# %%
car_01={
    'No':'1',
    'Brand':'Toyota',
    'Model':'Coralla',
    'Color':'Red'
}
car_02={
    'No':'2',
    'Brand':'Honda',
    'Model':'Civic',
    'Color':'Black'
}
car_03={
    'No':'3',
    'Brand':'BMW',
    'Model':'X5',
    'Color':'white'
}

car_infomatiion_list = [
    car_01,
    car_02,
    car_03
]

# %%
car_information_dict = [
    {
        'No':'1',
        'Brand':'Toyota',
        'Model':'Coralla',
        'Color':'Red'
    },
    {
        'No':'2',
        'Brand':'Honda',
        'Model':'Civic',
        'Color':'Black'
    }
]

# %%
# 딕션어리에서 특정값 확인
# car_information_dict[1]['Model']
car_information_dict[1]['Brand']
# Out:
# 'Civic'

# %% [markdown]
# ## 문제 1. 리스트 만들기
# 회사원 이름을 순서대로 리스트에 저장해 보세요.
#  리스트 이름: employees
# 번호
# 이름
# 1
# Alice
# 2
# Bob
# 3
# Charlie
# 4
# Diana
#
# # employees 리스트를 만들어 보세요
# # Alice 출력
# # Charlie 출력

# %%
employees = ['Alice', 'Bob', 'Charlie', 'Diana']
print(employees[0])
print(employees[2])
# Out:
# Alice
# Charlie

# %% [markdown]
# ## 문제 2. 딕셔너리 만들기
# 한 명의 회사원 정보를 딕셔너리로 만들어 보세요.
#  딕셔너리 이름: employee1
# 키
# 값
# name
# Alice
# department
# Sales
# position
# Manager
# year
# 2023
#
# # employee1 딕셔너리를 만들어 보세요
# # “Manager” 를 출력

# %%
employee1 = {
    'name':'Alice',
    'department':'Sales',
    'position':'Manager',
    'year':'20233'}

print(employee1['position'])
# Out:
# Manager

# %% [markdown]
# ---
# name
# deparment
# position
# year
# ---
# Alice
# Sales
# Manager
# 2023
# ---
# Bob
# IT
# Engineer
# 2022
# ---
# Charlie
# HR
# Staff
# 2023
# ---
# Diana
# Marketing
# Analyst
# 2024
# ---
# ## 문제 3. 리스트 안 딕셔너리 만들기
# 여러 회사원의 정보를 리스트 안 딕셔너리 형태로 만들어 보세요.
#  리스트 이름: all_employees# all_employees 리스트 안에 딕셔너리를 만들어 보세요
# ## 3 번째 직원 정보 출력
# # 2 번째 position 출력

# %%
employee_01= {
  'name':'Alice',
  'department':'Sales',
  'position':'Manager',
  'year':'2023'
}
employee_02= {
    'name':'Bob',
    'department':'IT',
    'position':'Engineer',
    'year':'2022'
}
employee_03= {
    'name':'Charlie',
    'department':'HR',
    'position':'Staff',
    'year':'2023'
}
employee_04= {
    'name':'Diana',
    'department':'Marketing',
    'position':'Analyst',
    'year':'2024'
}

all_employees= [
     employee_01,
     employee_02,
     employee_03,
     employee_04
 ]
print(all_employees[2])
print(all_employees[1]['position'])
# Out:
# {'name': 'Charlie', 'department': 'HR', 'position': 'Staff', 'year': '2023'}
# Engineer
