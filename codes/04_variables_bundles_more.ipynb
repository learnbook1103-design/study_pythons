# %% [markdown]
# ## 단계 1. 리스트 안의 딕셔너리
# 다음과 같은 리스트가 있습니다.
#  리스트에서 첫 번째 직원과 두 번째 직원 이름을 각각 출력해 보세요.
# employees = [
#     {"name": "Alice", "department": "Sales"},
#     {"name": "Bob", "department": "IT"},
#     {"name": "Charlie", "department": "HR"}
# ]

# %%
employees=[ {"name": "Alice", "department": "Sales"},
            {"name": "Bob", "department": "IT"},
            {"name": "Charlie", "department": "HR"} ]
# 첫 번째 직원 이름 출력
print(employees[0]['name'])
# 두 번째 직원 이름 출력
print(employees[1]['name'])
# Out:
# Alice
# Bob

# %% [markdown]
# ## 2단계: 리스트 안의 딕셔너리
# 구조: [ { } , { } , { } ]
#  → 리스트에 여러 개의 딕셔너리가 들어있는 형태
#
# 📝 예제 1: 학생 정보
# [
#   {"name": "김민수", "age": "20", "major": "컴퓨터공학"},
#   {"name": "이영희", "age": "21", "major": "경영학"},
#   {"name": "박철수", "age": "22", "major": "디자인"}
# ]
#
# 📝 예제 2: 도서 정보
# [
#   {"title": "파이썬 기초", "author": "홍길동", "price": "25000"},
#   {"title": "자료구조", "author": "김철수", "price": "30000"},
#   {"title": "알고리즘", "author": "이영희", "price": "28000"}
# ]
#
# 📝 예제 3: 상품 정보
# [
#   {"name": "노트북", "brand": "삼성", "stock": "15"},
#   {"name": "마우스", "brand": "로지텍", "stock": "50"},
#   {"name": "키보드", "brand": "레오폴드", "stock": "30"}
# ]
#
# 📝 예제 4: 직원 정보
# [
#   {"name": "Alice", "department": "Sales", "position": "Manager"},
#   {"name": "Bob", "department": "IT", "position": "Engineer"},
#   {"name": "Charlie", "department": "HR", "position": "Staff"}
# ]
#
# 📝 예제 5: 영화 정보
# [
#   {"title": "인터스텔라", "director": "놀란", "year": "2014"},
#   {"title": "기생충", "director": "봉준호", "year": "2019"},
#   {"title": "어벤져스", "director": "루소", "year": "2019"}
# ]
#
# 📝 예제 6: 카페 메뉴
# [
#   {"name": "아메리카노", "size": "Tall", "price": "4500"},
#   {"name": "카페라떼", "size": "Grande", "price": "5000"},
#   {"name": "카푸치노", "size": "Venti", "price": "5500"}
# ]
#
# 📝 예제 7: 자동차 정보
# [
#   {"model": "소나타", "brand": "현대", "color": "흰색"},
#   {"model": "K5", "brand": "기아", "color": "검정"},
#   {"model": "SM6", "brand": "르노", "color": "은색"}
# ]

# %% [markdown]
# ### 문제 1
#  예제 1의 학생 정보를 students 변수에 만들고, 두 번째 학생의 이름을 출력하세요.

# %%
students=[ {"name": "김민수", "age": "20",
            "major": "컴퓨터공학"},
           {"name": "이영희",
            "age": "21", "major": "경영학"},
           {"name": "박철수",
            "age": "22", "major": "디자인"} ]
print(students[1]['name'])
# Out:
# 이영희

# %% [markdown]
# ### 문제 2
#  예제 2의 도서 정보를 books 변수에 만들고, 첫 번째 책의 저자를 출력하세요.

# %%
books= [ {"title": "파이썬 기초",
          "author": "홍길동",
          "price": "25000"},
         {"title": "자료구조",
          "author": "김철수",
          "price": "30000"},
         {"title": "알고리즘",
          "author": "이영희",
          "price": "28000"} ]
print(books[0]['author'])
# Out:
# 홍길동

# %% [markdown]
# ### 문제 3
#  예제 3의 상품 정보를 products 변수에 만들고, 세 번째 상품의 재고를 출력하세요.

# %%
products= [ {"name": "노트북",
             "brand": "삼성",
             "stock": "15"},
            {"name": "마우스",
             "brand": "로지텍",
             "stock": "50"},
            {"name": "키보드",
             "brand": "레오폴드",
             "stock": "30"} ]
print(products[2]['stock'])
# Out:
# 30

# %% [markdown]
# ### 문제 4
# 예제 4의 직원 정보를 employees 변수에 만들고, 두 번째 직원의 부서를 출력하세요.

# %%
employees= [ {"name": "Alice",
              "department": "Sales",
              "position": "Manager"},
             {"name": "Bob",
              "department": "IT",
              "position": "Engineer"},
             {"name": "Charlie",
              "department": "HR",
              "position": "Staff"} ]
print(employees[1]['department'])
# Out:
# IT

# %% [markdown]
# ### 문제 5
# 예제 5의 영화 정보를 movies 변수에 만들고, 세 번째 영화의 개봉 연도를 출력하세요.

# %%
movies=[ {"title": "인터스텔라",
          "director": "놀란",
          "year": "2014"},
         {"title": "기생충",
          "director": "봉준호",
          "year": "2019"},
         {"title": "어벤져스",
          "director": "루소",
          "year": "2019"} ]
print(movies[2]['year'])
# Out:
# 2019

# %% [markdown]
# ## 3단계: 딕셔너리 안의 리스트
# 구조: { "key": [ , , ] }
#  → 딕셔너리의 값으로 리스트가 들어있는 형태
#
# 📝 예제 1: 학급별 학생
# {
#   "1반": ["김민수", "이영희", "박철수"],
#   "2반": ["최지영", "정다은", "강민호"],
#   "3반": ["윤서준", "한지민"]
# }
#
# 📝 예제 2: 과일 가게 재고
# {
#   "사과": ["부사", "홍옥", "청송"],
#   "배": ["신고", "황금배"],
#   "포도": ["샤인머스캣", "MBA", "캠벨"]
# }
#
# 📝 예제 3: 부서별 직원
# {
#   "개발팀": ["김코딩", "이파이", "박자바"],
#   "디자인팀": ["최포샵", "정피그"],
#   "마케팅팀": ["한광고", "윤홍보", "강기획"]
# }
#
# 📝 예제 4: 음식 카테고리
# {
#   "한식": ["김치찌개", "된장찌개", "불고기"],
#   "중식": ["짜장면", "짬뽕", "탕수육"],
#   "일식": ["초밥", "라멘", "돈까스"]
# }
#
# 📝 예제 5: 과목별 수강생
# {
#   "Python": ["Alice", "Bob", "Charlie"],
#   "Java": ["David", "Eve"],
#   "JavaScript": ["Frank", "Grace", "Henry", "Irene"]
# }

# %% [markdown]
# ### 문제 1
#  예제 1의 학급 정보를 classes 변수에 만들고, "2반"의 첫 번째 학생을 출력하세요.

# %%
classes= { "1반": ["김민수", "이영희", "박철수"],
           "2반": ["최지영", "정다은", "강민호"],
           "3반": ["윤서준", "한지민"] }
print(classes["2반"][0])
# Out:
# 최지영

# %% [markdown]
# ### 문제 2
#  예제 2의 과일 정보를 fruits 변수에 만들고, "포도"의 세 번째 품종을 출력하세요.

# %%
fruits={ "사과": ["부사", "홍옥", "청송"],
         "배": ["신고", "황금배"],
         "포도": ["샤인머스캣", "MBA", "캠벨"] }
print(fruits["포도"][2])
# Out:
# 캠벨

# %% [markdown]
# ### 문제 3
#  예제 3의 부서 정보를 departments 변수에 만들고, "개발팀"의 모든 직원을 출력하세요.

# %%
departments={ "개발팀": ["김코딩", "이파이", "박자바"],
              "디자인팀": ["최포샵", "정피그"],
              "마케팅팀": ["한광고", "윤홍보", "강기획"] }
print(departments["개발팀"])
# Out:
# ['김코딩', '이파이', '박자바']

# %% [markdown]
# ### 문제 4
#  예제 4의 음식 정보를 foods 변수에 만들고, "중식"의 두 번째 메뉴를 출력하세요.

# %%
foods={ "한식": ["김치찌개", "된장찌개", "불고기"],
        "중식": ["짜장면", "짬뽕", "탕수육"],
        "일식": ["초밥", "라멘", "돈까스"] }
print(foods["중식"][1])
# Out:
# 짬뽕

# %% [markdown]
# ### 문제 5
#  예제 5의 과목 정보를 courses 변수에 만들고, "JavaScript"의 네 번째 수강생을 출력하세요.

# %%
courses={ "Python": ["Alice", "Bob", "Charlie"],
          "Java": ["David", "Eve"],
          "JavaScript": ["Frank", "Grace", "Henry", "Irene"] }
print(courses["JavaScript"][3])
# Out:
# Irene

# %% [markdown]
# ## 4단계: 리스트 안의 딕셔너리 안의 리스트
# 구조: [ { "key": [ , , ] } , { "key": [ , , ] } ]
#  → 리스트 안에 딕셔너리가 있고, 그 딕셔너리의 값이 리스트인 형태
#
# 📝 예제 1: 학교별 학급 정보
# [
#   {
#     "name": "서울고등학교",
#     "classes": {
#       "1학년": ["김민수", "이영희"],
#       "2학년": ["박철수", "최지영"]
#     }
#   },
#   {
#     "name": "부산고등학교",
#     "classes": {
#       "1학년": ["정다은", "강민호"],
#       "2학년": ["윤서준"]
#     }
#   }
# ]
#
# 📝 예제 2: 회사별 부서 정보
# [
#   {
#     "company": "A Corp",
#     "departments": {
#       "Sales": ["Alice", "Eve"],
#       "IT": ["Bob", "David"]
#     }
#   },
#   {
#     "company": "B Corp",
#     "departments": {
#       "HR": ["Charlie"],
#       "Marketing": ["Diana", "Frank"]
#     }
#   }
# ]
#
# 📝 예제 3: 쇼핑몰별 카테고리
# [
#   {
#     "mall": "패션몰",
#     "categories": {
#       "상의": ["티셔츠", "셔츠", "니트"],
#       "하의": ["청바지", "슬랙스"]
#     }
#   },
#   {
#     "mall": "전자몰",
#     "categories": {
#       "컴퓨터": ["노트북", "데스크탑"],
#       "주변기기": ["마우스", "키보드", "모니터"]
#     }
#   }
# ]
#
# 📝 예제 4: 도서관별 장르
# [
#   {
#     "name": "중앙도서관",
#     "genres": {
#       "소설": ["해리포터", "반지의제왕"],
#       "과학": ["코스모스", "이기적유전자"]
#     }
#   },
#   {
#     "name": "시립도서관",
#     "genres": {
#       "역사": ["총균쇠", "사피엔스"],
#       "경제": ["국부론", "자본론"]
#     }
#   }
# ]
#
# 📝 예제 5: 식당별 메뉴
# [
#   {
#     "name": "한식당",
#     "menu": {
#       "찌개류": ["김치찌개", "된장찌개"],
#       "구이류": ["불고기", "삼겹살", "갈비"]
#     }
#   },
#   {
#     "name": "중식당",
#     "menu": {
#       "면류": ["짜장면", "짬뽕"],
#       "요리": ["탕수육", "깐풍기"]
#     }
#   }
# ]

# %% [markdown]
# ### 문제 1
#  예제 1의 학교 정보를 schools 변수에 만들고, 첫 번째 학교의 이름을 출력하세요.

# %%
schools=[ { "name": "서울고등학교",
            "classes": { "1학년": ["김민수", "이영희"],
                         "2학년": ["박철수", "최지영"] } },
          { "name": "부산고등학교",
            "classes": { "1학년": ["정다은", "강민호"],
                         "2학년": ["윤서준"] } } ]
print(schools[0]['name'])
# Out:
# 서울고등학교

# %% [markdown]
# ### 문제 2
#  예제 2의 회사 정보를 companies 변수에 만들고, 첫 번째 회사("A Corp")의 "Sales" 부서 직원 목록을 출력하세요.

# %%
companies= [ { "company": "A Corp",
               "departments": { "Sales": ["Alice", "Eve"],
                                "IT": ["Bob", "David"] } },
              { "company": "B Corp",
                "departments": { "HR": ["Charlie"],
                                 "Marketing": ["Diana", "Frank"] } } ]
print(companies[0]['departments']['Sales'])
# Out:
# ['Alice', 'Eve']

# %% [markdown]
# ### 문제 3
#  예제 3의 쇼핑몰 정보를 malls 변수에 만들고, 두 번째 쇼핑몰("전자몰")의 "주변기기" 카테고리의 첫 번째 상품을 출력하세요.

# %%
malls= [ { "mall": "패션몰",
           "categories": { "상의": ["티셔츠", "셔츠", "니트"],
                           "하의": ["청바지", "슬랙스"] } },
          { "mall": "전자몰",
            "categories": { "컴퓨터": ["노트북", "데스크탑"],
                            "주변기기": ["마우스", "키보드", "모니터"] } } ]
print(malls[1]['categories']['주변기기'][0])
# Out:
# 마우스

# %% [markdown]
# ### 문제 4
#  예제 4의 도서관 정보를 libraries 변수에 만들고, 두 번째 도서관의 "경제" 장르에서 두 번째 책을 출력하세요.

# %%
libraries=[ { "name": "중앙도서관",
              "genres": { "소설": ["해리포터", "반지의제왕"],
                          "과학": ["코스모스", "이기적유전자"] } },
            { "name": "시립도서관",
              "genres": { "역사": ["총균쇠", "사피엔스"],
                          "경제": ["국부론", "자본론"] } } ]
print(libraries[1]['genres']['경제'][1])
# Out:
# 자본론

# %% [markdown]
#  ### 문제 5
#  예제 5의 식당 정보를 restaurants 변수에 만들고, 첫 번째 식당("한식당")의 "구이류" 메뉴 중 세 번째 메뉴를 출력하세요.

# %%
restaurants=[ { "name": "한식당",
                "menu": { "찌개류": ["김치찌개", "된장찌개"],
                          "구이류": ["불고기", "삼겹살", "갈비"] } },
              { "name": "중식당",
                "menu": { "면류": ["짜장면", "짬뽕"],
                          "요리": ["탕수육", "깐풍기"] } } ]
print(restaurants[0]['menu']['구이류'][2])
# Out:
# 갈비
